# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql.functions import *
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.feature import StandardScaler
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.tuning import CrossValidator
from pyspark.ml.tuning import ParamGridBuilder
from pyspark.sql import SparkSession
from pyspark.ml.feature import StringIndexer
from pyspark.sql.types import *
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Set parquet configuration to interpret binary byte array as string
spark = SparkSession.builder.config('spark.sql.parquet.binaryAsString', 'true') \
            .config('spark.jars.packages', 'org.mongodb.spark:mongo-spark-connector_2.12:3.0.1')\
            .appName("OMS") \
            .getOrCreate()

# sc = spark.sparkContext
# sc.setLogLevel("ERROR")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: </div>
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=350987258500339#setting/sparkui/0305-222422-gawo7are/driver-2808769791499657946">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://10.215.233.75:7077</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# **Load Song Popularity Data**

# %%
database = 'oms'
collection = 'song_popularity_predictions_data'
user_name = 'user'
password = 'user'
address = 'oms-cluster.0navm.mongodb.net'
connection_string = f"mongodb+srv://{user_name}:{password}@{address}/{database}.{collection}"
df_song_pop = spark.read.format("mongo").option("uri",connection_string).load()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# **Loading Play count Data Set**

# %%
database = 'oms'
collection = 'play_counts'
user_name = 'user'
password = 'user'
address = 'oms-cluster.0navm.mongodb.net'
connection_string = f"mongodb+srv://{user_name}:{password}@{address}/{database}.{collection}"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_playcounts_ = spark.read.format("mongo").option("uri",connection_string).load()
df_playcounts =df_playcounts_.select('play_count', 'song_id', 'user_id').cache()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_playcounts.display(1)

# %% [markdown]
# **Load song Genre**

# %%
database = 'oms'
collection = 'song_genre'
user_name = 'user'
password = 'user'
address = 'oms-cluster.0navm.mongodb.net'
connection_string = f"mongodb+srv://{user_name}:{password}@{address}/{database}.{collection}"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_genre_ = spark.read.format("mongo").option("uri",connection_string).load()
df_genre = df_genre_.select('genre','song_id').cache()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_genre.display(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# **Joining the genre to playcount data**

# %%
df_genre_playcounts = df_genre.join(df_playcounts,'song_id' ,'inner').cache()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_genre_playcounts.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
df_genre_playcounts.display(10)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>song_id</th><th>genre</th><th>play_count</th><th>user_id</th></tr></thead><tbody><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>1</td><td>2199769200b689c44cd8442f51e4f82047ecf679</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>1</td><td>4af4db5cdd51f8cdd0917cc51fa9f53e7bcb031b</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>1</td><td>3b4ad4a00c1a8edb790435e9ea4ed6f354445f94</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>1</td><td>3a73046fe1a5aae7d8fa6173cbd053db85c00988</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>1</td><td>6fd7851e1d02a3aeaf90855bba34e72f9d256173</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>1</td><td>4b49956d0855007f80462b498f41e2a5b93a6f6e</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>1</td><td>f3fd89959b9a004eb8bc31c1e41f2b756a39927a</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>1</td><td>c6535de39bc7a062daf12a71be78e37e090dd3c6</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>1</td><td>bb84b605789d898993e2c6fbda4d57a8bc8da369</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>1</td><td>24145dac630d4f7c33544a12c054affd85358537</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>1</td><td>0d514a46b421bb03227fd493bec558ea36d656df</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>16</td><td>3f0e81b61cf13f3e4ec409aa90df10823c4fd1a3</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>6</td><td>988ce08d1a9876eeb9e55f0b7635e73ffbefaf03</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>1</td><td>72f6f9bb41ff068fd80fe62a9c156e8cd21cd4c4</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>1</td><td>14aad28a2f8c6ba0a97536b4aff170d00a410747</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>20</td><td>96edfbce577975ab46949525e0cad3482aaf9bb9</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>2</td><td>06e2112e9fa9a5305d95f11267ffa831c7e76c6d</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>7</td><td>c7390772e7c60b45b208dd8bdb86763c5273c8b9</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>3</td><td>fe7c9528e366d510a4b5e04cd3508fe97cd83491</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>1</td><td>148a8c86276275311173820967af49bd9e0d7907</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>1</td><td>0ba364be007519415e72615f72d9904332b29dd5</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>1</td><td>f71666ccf43ff6c5c1020b411140768b591aeaba</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>1</td><td>629fb3d9d8d8df4c07eb28510f3d564333a403df</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>1</td><td>7f668bf977749deec324a03cdec992e3eda30885</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>1</td><td>354e4a0751ec736d2a40357992b451c76f7b4ddb</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>1</td><td>c43a43beb5636a6ebaadedb6438ec06b4f6f726b</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>1</td><td>97c49ee46d566c54f4417c9cd2d5f342fbb42910</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>1</td><td>18ed798cd97f2ec70f0dea0719cf67b7fa48e3fc</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>1</td><td>bdc4ca0b28329a71badd4176878d7787302756ed</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>1</td><td>24b4cf712d4ea8bbcb09369c8de36fd100d30ac6</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>1</td><td>5c9cca411e4b9c865f41b7f5a7d5f62df486d75b</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>1</td><td>0cf47b46f7dba9eaa9c757c29b267dbd40bfd7b8</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>7</td><td>009db9e2f34b97d48f6583fd89999221c63ec4ed</td></tr><tr><td>SOAAZPG12A6D4F8D8B</td><td>Pop Rock</td><td>1</td><td>97b2b3ff5f03009594fa019c7b789a16277d714e ...

# %%
df_genre_playcounts_grouped =spark.sql("select genre, user_id, AVG(play_count) as avg_play_count from df_genre_playcounts group by genre, user_id")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_genre_playcounts.write.saveAsTable('default.df_genre_playcounts_grouped')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
top_genre = spark.sql("select genre, user_id, avg_play_count, rank() over (partition by genre order by avg_play_count desc ) as rank_ from df_genre_playcounts_grouped")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AnalysisException</span>                         Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3164413804757859&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>top_genre <span class="ansi-blue-fg">=</span> spark<span class="ansi-blue-fg">.</span>sql<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;select genre, user_id, avg_play_count, rank() over (partition by genre order by avg_play_count desc ) as rank_ from df_genre_playcounts_grouped&#34;</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/session.py</span> in <span class="ansi-cyan-fg">sql</span><span class="ansi-blue-fg">(self, sqlQuery)</span>
# <span class="ansi-green-intense-fg ansi-bold">    775</span>         <span class="ansi-blue-fg">[</span>Row<span class="ansi-blue-fg">(</span>f1<span class="ansi-blue-fg">=</span><span class="ansi-cyan-fg">1</span><span class="ansi-blue-fg">,</span> f2<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#39;row1&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span> Row<span class="ansi-blue-fg">(</span>f1<span class="ansi-blue-fg">=</span><span class="ansi-cyan-fg">2</span><span class="ansi-blue-fg">,</span> f2<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#39;row2&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span> Row<span class="ansi-blue-fg">(</span>f1<span class="ansi-blue-fg">=</span><span class="ansi-cyan-fg">3</span><span class="ansi-blue-fg">,</span> f2<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#39;row3&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">]</span>
# <span class="ansi-green-intense-fg ansi-bold">    776</span>         &#34;&#34;&#34;
# <span class="ansi-green-fg">--&gt; 777</span><span class="ansi-red-fg">         </span><span class="ansi-green-fg">return</span> DataFrame<span class="ansi-blue-fg">(</span>self<span class="ansi-blue-fg">.</span>_jsparkSession<span class="ansi-blue-fg">.</span>sql<span class="ansi-blue-fg">(</span>sqlQuery<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span> self<span class="ansi-blue-fg">.</span>_wrapped<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    778</span>
# <span class="ansi-green-intense-fg ansi-bold">    779</span>     <span class="ansi-green-fg">def</span> table<span class="ansi-blue-fg">(</span>self<span class="ansi-blue-fg">,</span> tableName<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.9.1-src.zip/py4j/java_gateway.py</span> in <span class="ansi-cyan-fg">__call__</span><span class="ansi-blue-fg">(self, *args)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1302</span>
# <span class="ansi-green-intense-fg ansi-bold">   1303</span>         answer <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>gateway_client<span class="ansi-blue-fg">.</span>send_command<span class="ansi-blue-fg">(</span>command<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">-&gt; 1304</span><span class="ansi-red-fg">         return_value = get_return_value(
# </span><span class="ansi-green-intense-fg ansi-bold">   1305</span>             answer, self.gateway_client, self.target_id, self.name)
# <span class="ansi-green-intense-fg ansi-bold">   1306</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">    121</span>                 <span class="ansi-red-fg"># Hide where the exception came from that shows a non-Pythonic</span>
# <span class="ansi-green-intense-fg ansi-bold">    122</span>                 <span class="ansi-red-fg"># JVM exception message.</span>
# <span class="ansi-green-fg">--&gt; 123</span><span class="ansi-red-fg">                 </span><span class="ansi-green-fg">raise</span> converted <span class="ansi-green-fg">from</span> <span class="ansi-green-fg">None</span>
# <span class="ansi-green-intense-fg ansi-bold">    124</span>             <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    125</span>                 <span class="ansi-green-fg">raise</span>
#
# <span class="ansi-red-fg">AnalysisException</span>: Table or view not found: df_genre_playcounts_grouped; line 1 pos 116;
# &#39;Project [&#39;genre, &#39;user_id, &#39;avg_play_count, rank() windowspecdefinition(&#39;genre, &#39;avg_play_count DESC NULLS LAST, specifiedwindowframe(RowFrame, unboundedpreceding$(), currentrow$())) AS rank_#505]
# +- &#39;UnresolvedRelation [df_genre_playcounts_grouped], [], false
# </div>

# %%
top_genre.display(10)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>song_id</th><th>genre</th><th>user_id</th><th>play_count</th><th>rank_</th></tr></thead><tbody><tr><td>SOYFYHE12A8C142082</td><td>International</td><td>dcf6a11b2fea3af24fb001f504851ed23aae9965</td><td>686</td><td>1</td></tr><tr><td>SOZGGXU12A67ADD3E4</td><td>International</td><td>762c6fa3791c68f5b530b91a3413a8f480df2099</td><td>407</td><td>2</td></tr><tr><td>SOAJDBZ12A6D4FA3C8</td><td>International</td><td>e3d47f8d33e91da3c476577cdf0b5dc3fe1e2d2a</td><td>296</td><td>3</td></tr><tr><td>SOZGGXU12A67ADD3E4</td><td>International</td><td>8cbcb30da89e66b46136dca4f3ab5d70893f7db8</td><td>229</td><td>4</td></tr><tr><td>SOAJDBZ12A6D4FA3C8</td><td>International</td><td>e3f6ac98a2b45f6ac0b0b1e118774828d8be2029</td><td>227</td><td>5</td></tr><tr><td>SOMECGO12AB0186D31</td><td>International</td><td>d9b255c131ba531ef58a393e3c5fb3f43f2dc53c</td><td>224</td><td>6</td></tr><tr><td>SOCSAOO12AB017E850</td><td>International</td><td>3cc0475a6842e690fc9ed3dcf232ead0fd01e0c5</td><td>167</td><td>7</td></tr><tr><td>SOUWNIQ12A67ADE5B6</td><td>International</td><td>64074f44ffae272464a75b3ca3fbcddcec95eda6</td><td>160</td><td>8</td></tr><tr><td>SOSBZQZ12A6D4FA577</td><td>International</td><td>52eeb1ecde85689adc8bd3c6f393a6ff04f9aaba</td><td>156</td><td>9</td></tr><tr><td>SOAJDBZ12A6D4FA3C8</td><td>International</td><td>6aa76847a05f6f10fcd7c1bf4ed6f6ab1ac4e90e</td><td>150</td><td>10</td></tr><tr><td>SOCSAOO12AB017E850</td><td>International</td><td>eead778628d156cb05b8712f6b1493ee4dba3c66</td><td>147</td><td>11</td></tr><tr><td>SOUWKRY12A6D4FB676</td><td>International</td><td>ea8d489de5d9b66b16ae7df0dae5fb19d3377bd8</td><td>144</td><td>12</td></tr><tr><td>SOZGGXU12A67ADD3E4</td><td>International</td><td>a378833beac386a01334e
td><td>SOKNMJE12A67AE0421</td><td>Electronic</td><td>1369</td></tr><tr><td>780913e6a5d61405f4653aef0231876e6721120b</td><td>SOOWJZM12A6D4F7995</td><td>1</td><td>SOKNMJE12A67AE0421</td><td>Electronic</td><td>1369</td></tr><tr><td>780913e6a5d61405f4653aef0231876e6721120b</td><td>SOSFOFO12AF72AD198</td><td>2</td><td>SOKNMJE12A67AE0421</td><td>Electronic</td><td>1369</td></tr><tr><td>780913e6a5d61405f4653aef0231876e6721120b</td><td>SOTVFIU12AC46878B7</td><td>1</td><td>SOKNMJE12A67AE0421</td><td>Electronic</td><td>1369</td></tr><tr><td>780913e6a5d61405f4653aef0231876e6721120b</td><td>SOTZQAD12A8C13A8F7</td><td>2</td><td>SOKNMJE12A67AE0421</td><td>Electronic</td><td>1369</td></tr><tr><td>b866b293d1cb7509fcbc43316c46da4b2a163d85</td><td>SOACPBY12A8C13FEF9</td><td>1</td><td>SOARTRF12AB0181F4D</td><td>Latin</td><td>551</td></tr><tr><td>b866b293d1cb7509fcbc43316c46da4b2a163d85</td><td>SOAMSVG12A81C20B26</td><td>6</td><td>SOARTRF12AB0181F4D</td><td>Latin</td><td>551</td></tr><tr><td>b866b293d1cb7509fcbc43316c46da4b2a163d85</td><td>SOARTRF12AB0181F4D</td><td>551</td><td>SOARTRF12AB0181F4D</td><td>Latin</td><td>551</td></tr><tr><td>b866b293d1cb7509fcbc43316c46da4b2a163d85</td><td>SOCHPTV12A6BD53113</td><td>1</td><td>SOARTRF12AB0181F4D</td><td>Latin</td><td>551</td></tr><tr><td>b866b293d1cb7509fcbc43316c46da4b2a163d85</td><td>SOFATVL12A8C13A4FC</td><td>15</td><td>SOARTRF12AB0181F4D</td><td>Latin</td><td>551</td></tr><tr><td>b866b293d1cb7509fcbc43316c46da4b2a163d85</td><td>SOFDJSB12AB0183B5B</td><td>1</td><td>SOARTRF12AB0181F4D</td><td>Latin</td><td>551</td></tr><tr><td>b866b293d1cb7509fcbc43316c46da4b2a163d85</td><td>SOFFLEN12A3F1EB0C5</td><td>10</td><td>SOARTRF12AB0181F4D</td><td>Latin</td><td>551</td></tr><tr><td>b866b293d1cb7509fcbc43316c46da4b2a163d85</td><td>SOFPJGB12A8C143EA1</td><td>18</td><td>SOARTRF12AB0181F4D</td><td>Latin</td><td>551</td></tr><tr><td>b866b293d1cb7509fcbc43316c46da4b2a163d85</td><td>SOHOZFL12AB018266A</td><td>1</td><td>SOARTRF12AB0181F4D</td><td>Latin</td><td>551</td></tr><tr><td>b866b293d1cb7509fcbc43316c46da4b2a163d85</td><td>SOLGPOU12A58A7EA20</td><td>34</td><td>SOARTRF12AB0181F4D</td><td>Latin</td><td>551</td></tr><tr><td>b866b293d1cb7509fcbc43316c46da4b2a163d85</td><td>SOMGKXK12A8C1430B3</td><td>2</td><td>SOARTRF12AB0181F4D</td><td>Latin</td><td>551</td></tr><tr><td>b866b293d1cb7509fcbc43316c46da4b2a163d85</td><td>SOMQEIE12A58A78309</td><td>3</td><td>SOARTRF12AB0181F4D</td><td>Latin</td><td>551</td></tr><tr><td>b866b293d1cb7509fcbc43316c46da4b2a163d85</td><td>SOPSAEJ12A58A7DA0F</td><td>8</td><td>SOARTRF12AB0181F4D</td><td>Latin</td><td>551</td></tr><tr><td>b866b293d1cb7509fcbc43316c46da4b2a163d85</td><td>SORFIPH12AB018BD90</td><td>17</td><td>SOARTRF12AB0181F4D</td><td>Latin</td><td> ...

# %%
df_first_page.write.saveAsTable('default.df_first_page_data')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[87]: 1142</div>

# %%
spark.read.table(df_first_page)

# %% [markdown]
# # For page-2 : Customized songs

# %%
database = 'oms'
collection = 'recommendations'
user_name = 'user'
password = 'user'
address = 'oms-cluster.0navm.mongodb.net'
connection_string = f"mongodb+srv://{user_name}:{password}@{address}/{database}.{collection}"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_song_emb = spark.read.format("mongo").option("uri",connection_string).load()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_song_emb.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- _id: struct (nullable = true)
#     |-- oid: string (nullable = true)
# -- recommendations: array (nullable = true)
#     |-- element: struct (containsNull = true)
#     |    |-- song_id-num: integer (nullable = true)
#     |    |-- rating: double (nullable = true)
# -- user_id-num: integer (nullable = true)
#
# </div>

# %%
df_song_emb2 = df_song_emb.select("user_id-num","recommendations.song_id-num","recommendations.rating")\
.withColumn("tmp", arrays_zip("song_id-num", "rating"))\
.withColumn("tmp", explode("tmp"))\
.select("user_id-num", col("tmp.song_id-num"), col("tmp.rating"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
users_table =spark.read.table( "default.df_first_page_final")
users_profile= users_table.select('user_id').drop_duplicates(subset=['user_id'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
database = 'oms'
collection = 'play_counts'
user_name = 'user'
password = 'user'
address = 'oms-cluster.0navm.mongodb.net'
connection_string = f"mongodb+srv://{user_name}:{password}@{address}/{database}.{collection}"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
mapping = spark.read.format("mongo").option("uri",connection_string).load()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
user_mapping = mapping.drop_duplicates(subset=['user_id']).select('user_id','user_id-num')
item_mapping = mapping.drop_duplicates(subset=['song_id']).select('song_id','song_id-num')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_recom=df_song_emb2.join(user_mapping,on='user_id-num').join(item_mapping,on='song_id-num')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_recom.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+-----------+------------------+--------------------+------------------+
# song_id-num|user_id-num|            rating|             user_id|           song_id|
# +-----------+-----------+------------------+--------------------+------------------+
#      119446|     242054| 91.92654418945312|7ea1591c5f5e28e51...|SOPJFAP12A8C13354E|
#      119446|     411296| 39.21882629394531|af9be2592a4bdcabd...|SOPJFAP12A8C13354E|
#       49948|       1051| 35.39113235473633|625d0167edbc5df88...|SONSTND12AB018516E|
#       49948|       1722|24.870309829711914|0bce287393918172e...|SONSTND12AB018516E|
#       49948|       2523| 28.51594352722168|00749571b48a89836...|SONSTND12AB018516E|
#       49948|       2793|27.462955474853516|5e81745a6d737e9bf...|SONSTND12AB018516E|
#       49948|       3523|21.684375762939453|8ae407182211fea39...|SONSTND12AB018516E|
#       49948|       4552|62.388492584228516|16dc7653772821c2b...|SONSTND12AB018516E|
#       49948|       4777|21.912599563598633|8f3dd78c0b895c028...|SONSTND12AB018516E|
#       49948|       4936|45.897220611572266|a838844b250a46717...|SONSTND12AB018516E|
#       49948|       5642|15.298616409301758|33021835175a5a323...|SONSTND12AB018516E|
#       49948|       6074| 41.06019592285156|2086b2b1b0eab0e88...|SONSTND12AB018516E|
#       49948|       6989| 24.50994300842285|8feb41d711fd050d8...|SONSTND12AB018516E|
#       49948|       8776|   67.425537109375|a4493d7bb8c07dc19...|SONSTND12AB018516E|
#       49948|       9399| 29.62091064453125|b6b47f0d757730b0c...|SONSTND12AB018516E|
#       49948|       9711|21.606252670288086|d7d68496808ec1b25...|SONSTND12AB018516E|
#       49948|      10380|21.476198196411133|e60d1431037786864...|SONSTND12AB018516E|
#       49948|      10474|26.262908935546875|cf46843745044ce8f...|SONSTND12AB018516E|
#       49948|      10690| 73.92153930664062|b490a8205a2749043...|SONSTND12AB018516E|
#       49948|      11530| 32.99009323120117|52cf6d3fc0f7c5c92...|SONSTND12AB018516E|
# +-----------+-----------+------------------+--------------------+------------------+
# only showing top 20 rows
#
# </div>

# %%
from pyspark.sql.functions import broadcast

page2 =df_recom.join(broadcast(users_profile ), on='user_id')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
page2.cache()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[83]: DataFrame[user_id: string, song_id-num: int, user_id-num: int, rating: double, song_id: string]</div>

# %%
database = 'oms'
collection = 'song_popularity_predictions_data'
user_name = 'user'
password = 'user'
address = 'oms-cluster.0navm.mongodb.net'
connection_string = f"mongodb+srv://{user_name}:{password}@{address}/{database}.{collection}"
df_song_pop = spark.read.format("mongo").option("uri",connection_string).load()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
page2_pop= page2.join(df_song_pop.select('song_id','prediction') ,on='song_id')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AnalysisException</span>                         Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3164413804759388&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>df_song_pop_sub <span class="ansi-blue-fg">=</span> df_song_pop<span class="ansi-blue-fg">.</span>join<span class="ansi-blue-fg">(</span> broadcast<span class="ansi-blue-fg">(</span>users_profile<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span>on<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#39;song_id&#39;</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/dataframe.py</span> in <span class="ansi-cyan-fg">join</span><span class="ansi-blue-fg">(self, other, on, how)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1378</span>                 on <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>_jseq<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1379</span>             <span class="ansi-green-fg">assert</span> isinstance<span class="ansi-blue-fg">(</span>how<span class="ansi-blue-fg">,</span> str<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;how should be a string&#34;</span>
# <span class="ansi-green-fg">-&gt; 1380</span><span class="ansi-red-fg">             </span>jdf <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>_jdf<span class="ansi-blue-fg">.</span>join<span class="ansi-blue-fg">(</span>other<span class="ansi-blue-fg">.</span>_jdf<span class="ansi-blue-fg">,</span> on<span class="ansi-blue-fg">,</span> how<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1381</span>         <span class="ansi-green-fg">return</span> DataFrame<span class="ansi-blue-fg">(</span>jdf<span class="ansi-blue-fg">,</span> self<span class="ansi-blue-fg">.</span>sql_ctx<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1382</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.9.1-src.zip/py4j/java_gateway.py</span> in <span class="ansi-cyan-fg">__call__</span><span class="ansi-blue-fg">(self, *args)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1302</span>
# <span class="ansi-green-intense-fg ansi-bold">   1303</span>         answer <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>gateway_client<span class="ansi-blue-fg">.</span>send_command<span class="ansi-blue-fg">(</span>command<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">-&gt; 1304</span><span class="ansi-red-fg">         return_value = get_return_value(
# </span><span class="ansi-green-intense-fg ansi-bold">   1305</span>             answer, self.gateway_client, self.target_id, self.name)
# <span class="ansi-green-intense-fg ansi-bold">   1306</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">    121</span>                 <span class="ansi-red-fg"># Hide where the exception came from that shows a non-Pythonic</span>
# <span class="ansi-green-intense-fg ansi-bold">    122</span>                 <span class="ansi-red-fg"># JVM exception message.</span>
# <span class="ansi-green-fg">--&gt; 123</span><span class="ansi-red-fg">                 </span><span class="ansi-green-fg">raise</span> converted <span class="ansi-green-fg">from</span> <span class="ansi-green-fg">None</span>
# <span class="ansi-green-intense-fg ansi-bold">    124</span>             <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    125</span>                 <span class="ansi-green-fg">raise</span>
#
# <span class="ansi-red-fg">AnalysisException</span>: USING column `song_id` cannot be resolved on the right side of the join. The right-side columns: [user_id]</div>

# %%
page2.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[75]: 210</div>

# %%
page2_pop = broadcast( page2).join( df_song_pop.select('song_id','prediction','artist_name','title') , on ='song_id' )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
page2_pop.cache()
page2_pop.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>song_id</th><th>user_id</th><th>song_id-num</th><th>user_id-num</th><th>rating</th><th>prediction</th><th>artist_name</th><th>title</th></tr></thead><tbody><tr><td>SORSXPU12A8C138ABB</td><td>6a145b64e3f73ea3018ed88c790c0804c2176ccd</td><td>250662</td><td>603137</td><td>87.71204376220703</td><td>0.2998774882739778</td><td>Armchair Martian</td><td>The Credible Hulk (1995)</td></tr><tr><td>SOFNLOY12A8C1339C7</td><td>98cb9a3feb48d15a8328ce16f1b32609698e11f2</td><td>272445</td><td>586630</td><td>1377.10986328125</td><td>0.402548583328269</td><td>Basement Jaxx</td><td>U Dont Know Me (Original Radio Mix)</td></tr><tr><td>SOZLVDB12AF72A25EA</td><td>6a145b64e3f73ea3018ed88c790c0804c2176ccd</td><td>116535</td><td>603137</td><td>100.81348419189453</td><td>0.3347065490692206</td><td>Mystikal featuring Snoop Dogg & Silkk The Shocker</td><td>Let's Go Do It</td></tr><tr><td>SOFRRFT12A8C140C5C</td><td>af8b6cf5ad80a0f5696192586824783a49c29805</td><td>158233</td><td>630473</td><td>1019.0083618164062</td><td>0.34580223396532944</td><td>Jack the Ripper</td><td>Words</td></tr><tr><td>SOEGPHZ12AB0187E42</td><td>d4ca0ff508531f8e2f
td><td>d8e6fa08d73821f305b9a3af1cf1e0a704473d82</td><td>187095</td><td>77932</td><td>3841.816650390625</td><td>0.3016817567316363</td><td>Beenie Man</td><td>Bad Man Story</td><td>5</td></tr><tr><td>SODUWZY12AB0183594</td><td>d8e6fa08d73821f305b9a3af1cf1e0a704473d82</td><td>120472</td><td>77932</td><td>3604.010009765625</td><td>0.29987662989261593</td><td>Th ...

# %% [markdown]
# **Popular Songs**

# %%
database = 'oms'
collection = 'play_counts'
user_name = 'user'
password = 'user'
address = 'oms-cluster.0navm.mongodb.net'
connection_string = f"mongodb+srv://{user_name}:{password}@{address}/{database}.{collection}"
df_play_counts = spark.read.format("mongo").option("uri",connection_string).load()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_songs_count =df_play_counts.groupBy('song_id').agg(sum('play_count').alias("total_play_count")).orderBy('total_play_count',ascending=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_songs_count.limit(10).select('song_id').collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: [Row(song_id=&#39;SOBONKR12A58A7A7E0&#39;),
#  Row(song_id=&#39;SOAUWYT12A81C206F1&#39;),
#  Row(song_id=&#39;SOSXLTC12AF72A7F54&#39;),
#  Row(song_id=&#39;SOFRQTD12A81C233C0&#39;),
#  Row(song_id=&#39;SOEGIYH12A6D4FC0E3&#39;),
#  Row(song_id=&#39;SOAXGDH12A8C13F8A1&#39;),
#  Row(song_id=&#39;SONYKOW12AB01849C9&#39;),
#  Row(song_id=&#39;SOPUCYA12A8C13A694&#39;),
#  Row(song_id=&#39;SOUFTBI12AB0183F65&#39;),
#  Row(song_id=&#39;SOVDSJC12A58A7A271&#39;)]</div>

# %%
top_list = ['SOBONKR12A58A7A7E0','SOAUWYT12A81C206F1','SOSXLTC12AF72A7F54','SOFRQTD12A81C233C0','SOEGIYH12A6D4FC0E3','SOAXGDH12A8C13F8A1'\
            ,'SONYKOW12AB01849C9','SOPUCYA12A8C13A694','SOUFTBI12AB0183F65','SOVDSJC12A58A7A271']
popular_songs =df_song_pop.filter(df_song_pop.song_id.isin(top_list)).select('song_id','prediction','artist_name','title')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
popular_songs.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>song_id</th><th>prediction</th><th>artist_name</th><th>title</th></tr></thead><tbody><tr><td>SOVDSJC12A58A7A271</td><td>0.5419947473131744</td><td>Sam Cooke</td><td>Ain't Misbehavin</td></tr><tr><td>SOAUWYT12A81C206F1</td><td>0.9374431571868832</td><td>Björk</td><td>Undo</td></tr><tr><td>SOAXGDH12A8C13F8A1</td><td>1.0</td><td>Florence + The Machine</td><td>Dog Days Are Over (Radio Edit)</td></tr><tr><td>SOSXLTC12AF72A7F54</td><td>0.9184270923627972</td><td>Kings Of Leon</td><td>Revelry</td></tr><tr><td>SOUFTBI12AB0183F65</td><td>0.4137398358601097</td><td>Tub Ring</td><td>Invalid</td></tr><tr><td>SONYKOW12AB01849C9</td><td>1.0</td><td>OneRepublic</td><td>Secrets</td></tr><tr><td>SOPUCYA12A8C13A694</td><td>0.34580223396532944</td><td>Five Iron Frenzy</td><td>Canada</td></tr><tr><td>SOFRQTD12A81C233C0</td><td>1.0</td><td>Harmonia</td><td>Sehr kosmisch</td></tr><tr><td>SOBONKR12A58A7A7E0</td><td>0.476435219642529</td><td>Dwight Yoakam</td><td>You're The One</td></tr><tr><td>SOEGIYH12A6D4FC0E3</td><td>-0.0038567672310621526</td><td>Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner</td><td>Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)</td></tr></tbody></table></div>
