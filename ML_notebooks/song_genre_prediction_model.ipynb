# %% [markdown]
# **Name**: Melvin Vellera
# **Analytic Goal**: Predict genre of a song
# **Machine Learning Algorithms**: Random Forest, Logistic Regression
# **Cluster**: 3 Node i3.xlarge cluster with v.10.3 (includes Apache Spark 3.2.1, Scala 2.12)

# %%
from time import time
start = time()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql.functions import *
from pyspark.ml.feature import StringIndexer
from pyspark.ml.feature import OneHotEncoder
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.tuning import CrossValidator
from pyspark.ml.tuning import ParamGridBuilder
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.classification import RandomForestClassifier, LogisticRegression
from pyspark.ml.linalg import Vectors, VectorUDT
from pyspark.sql.functions import udf
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def indexStringColumns(train, test, cols):
    for c in cols:
        si = StringIndexer(inputCol=c, outputCol=c+"-num")
        si_model = si.fit(train)
        train = si_model.transform(train)
        test = si_model.transform(test)
        train = train.drop(c).withColumnRenamed(c+"-num", c)
        test = test.drop(c).withColumnRenamed(c+"-num", c)
    return train, test

def oneHotEncodeColumns(train, test, cols):
    for c in cols:
        ohe = OneHotEncoder(inputCol=c, outputCol=c+"-onehot", dropLast=False)
        ohe_model = ohe.fit(train)
        train = ohe_model.transform(train)
        test = ohe_model.transform(test)
        train = train.drop(c).withColumnRenamed(c+"-onehot", c)
        test = test.drop(c).withColumnRenamed(c+"-onehot", c)
    return train, test
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark = SparkSession.builder.config('spark.jars.packages', 'org.mongodb.spark:mongo-spark-connector_2.12:3.0.1')\
            .config('spark.jars.packages', 'org.apache.hadoop:hadoop-aws:3.3.1')\
            .config("spark.network.timeout", "36000000s")\
            .config("spark.executor.heartbeatInterval", "3600s")\
            .config("spark.dynamicAllocation.enabled", "false")\
            .appName("OMS") \
            .getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Specify MongoDB configuration for pulling data
database = 'oms'
collection = 'song_genre'
user_name = 'oms'
password = 'oms'
address = 'oms-cluster.0navm.mongodb.net'
connection_string = f"mongodb+srv://{user_name}:{password}@{address}/{database}.{collection}"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Import data from MongoDb

# %%
# Read data from MongoDb
df = spark.read.format("mongo").option("uri",connection_string).load()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# View data
df.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------------+------------------+---------------+---------------+----------------+---------------+------------+---------+------+---------+---+--------+--------------------+----+------------------+-----------------+-------+--------------+--------------------+------------------+-----+
#                  _id|analysis_sample_rate|         artist_id|artist_latitude|artist_location|artist_longitude|    artist_name|danceability| duration|energy|    genre|key|loudness|    lyrics_embedding|mode|           song_id|start_of_fade_out|  tempo|time_signature|               title|          track_id| year|
# +--------------------+--------------------+------------------+---------------+---------------+----------------+---------------+------------+---------+------+---------+---+--------+--------------------+----+------------------+-----------------+-------+--------------+--------------------+------------------+-----+
# {622beeb604298143...|               22050|AROFSLD1187B99018B|       51.27597| Canterbury, UK|         1.07561|       Arzachel|         0.0|163.94404|   0.0| Pop Rock|  4|  -13.21|[0.26983049323904...|   0|SOKGPSO12AB0187077|          156.955|112.678|             4|Garden of Earthly...|TRABBGS128F934EE17|1960s|
# {622beeb604298143...|               22050|ARUB0K61187B9B9AC3|       29.65195|Gainesville, FL|       -82.32318|Hot Water Music|         0.0|169.50812|   0.0| Pop Rock|  2|  -4.804|[0.10246522209969...|   1|SOMVUXI12A8C139832|          157.304| 98.475|             4|       Trusty Chords|TRABBHI128F426260D|2000s|
# {622beeb604298143...|               22050|ARDDTL91187B9974A7|           null|               |            null|Warren Barfield|         0.0|207.51628|   0.0|Religious| 11|  -6.748|[-0.7184987927625...|   1|SOYVONC12AB0187167|          197.416|117.985|             4|              Shadow|TRACHFO12903CB3009|2000s|
# {622beeb604298143...|               22050|ARYWN7S1187FB43A41|       38.53492|    Ironton, OH|       -82.68448|     Bobby Bare|         0.0| 137.7171|   0.0|  Country|  2|  -9.248|[-0.0193135649213...|   1|SOOHFTV12A8C13D3E8|           128.47|154.252|             4|Help Me Make It T...|TRACPLH128F428D852|1990s|
# {622beeb604298143...|               22050|ARQ0BZY1187B99F093|           null|   Columbus, OH|            null|Everyday Sunday|         0.0|269.73995|   0.0|Religious|  7|  -7.462|[0.08777822833118...|   1|SOHKEPR12AB018C9C9|          250.358|103.009|             4|         Don&#39;t Leave|TRACRON12903CB59E6|2000s|
# +--------------------+--------------------+------------------+---------------+---------------+----------------+---------------+------------+---------+------+---------+---+--------+--------------------+----+------------------+-----------------+-------+--------------+--------------------+------------------+-----+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# #### Preprocess data to make it suitable for modeling

# %%
# Filter the dataframe to discard columns that are ids or have missing values
filtered_df = df.select("year", "danceability", "duration", "energy", "key", "loudness", "mode", 
                         "start_of_fade_out", "tempo", "time_signature", "lyrics_embedding", "genre")
filtered_df.cache()
filtered_df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: 116758</div>

# %%
# Get summary of the selected columns
filtered_df.summary().display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>year</th><th>danceability</th><th>duration</th><th>energy</th><th>key</th><th>loudness</th><th>mode</th><th>start_of_fade_out</th><th>tempo</th><th>time_signature</th><th>genre</th></tr></thead><tbody><tr><td>count</td><td>116758</td><td>116758</td><td>116758</td><td>116758</td><td>116758</td><td>116758</td><td>116758</td><td>116758</td><td>116758</td><td>116758</td><td>116758</td></tr><tr><td>mean</td><td>null</td><td>0.0</td><td>238.16662380873242</td><td>0.0</td><td>5.282490279038695</td><td>-8.37901927919287</td><td>0.6832936501139109</td><td>228.96376347658523</td><td>126.72507448740245</td><td>3.6539252128333817</td><td>null</td></tr><tr><td>stddev</td><td>null</td><td>0.0</td><td>90.43637062858336</td><td>0.0</td><td>3.5637849128748544</td><td>4.096195070708321</td><td>0.4651938211965309</td><td>88.58162056559385</td><td>34.507761103844594</td><td>1.126713853940391</td><td>null</td></tr><tr><td>min</td><td>1920s</td><td>0.0</td><td>0.522</td><td>0.0</td><td>0</td><td>-47.441</td><td>0</td><td>0.522</td><td>0.0</td><td>0</td><td>Avant Garde</td></tr><tr><td>25%</td><td>null</td><td>0.0</td><td>189.962</td><td>0.0</td><td>2</td><td>-10.578</td><td>0</td><td>181.841</td><td>100.007</td><td>4</td><td>null</td></tr><tr><td>50%</td><td>null</td><td>0.0</td><td>228.98893</td><td>0.0</td><td>5</td><td>-7.391</td><td>1</td><td>219.469</td><td>123.323</td><td>4</td><td>null</td></tr><tr><td>75%</td><td>null</td><td>0.0</td><td>272.3522</td><td>0.0</td><td>9</td><td>-5.368</td><td>1</td><td>261.851</td><td>148.763</td><td>4</td><td>null</td></tr><tr><td>max</td><td>2010s</td><td>0.0</td><td>3024.66567</td><td>0.0</td><td>11</td><td>2.865</td><td>1</td><td>3020.301</td><td>280.955</td><td>7</td><td>Vocal</td></tr></tbody></table></div>

# %% [markdown]
# We can see from the above summary that danceability and energy columns have a single value only (constant columns)

# %%
#Remove constant columns
filtered_df = filtered_df.drop("danceability", "energy")
filtered_df.cache()
filtered_df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: 116758</div>

# %%
# Check if any null values are present in any column
{col:filtered_df.filter(filtered_df[col].isNull()).count() for col in filtered_df.columns}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: {&#39;year&#39;: 0,
#  &#39;duration&#39;: 0,
#  &#39;key&#39;: 0,
#  &#39;loudness&#39;: 0,
#  &#39;mode&#39;: 0,
#  &#39;start_of_fade_out&#39;: 0,
#  &#39;tempo&#39;: 0,
#  &#39;time_signature&#39;: 0,
#  &#39;lyrics_embedding&#39;: 0,
#  &#39;genre&#39;: 0}</div>

# %%
# Check unique genres and the number of output classes (genre)
unique_genre = filtered_df.select('genre').distinct()
n_output_classes = unique_genre.count()
print(n_output_classes)
unique_genre.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">21
# +--------------+
#          genre|
# +--------------+
#  International|
#          Latin|
#           Jazz|
#        New Age|
#           Folk|
#            RnB|
#        Holiday|
#         Stage |
#    Avant Garde|
#       Pop Rock|
#          Vocal|
#      Classical|
#          Blues|
#  Comedy Spoken|
#      Religious|
# Easy Listening|
#            Rap|
#         Reggae|
#     Electronic|
#        Country|
# +--------------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# #### Split data into train and test

# %%
# Split data into train and test
train_test_df = filtered_df.randomSplit([0.8, 0.2], 1)
train_df = train_test_df[0]
test_df = train_test_df[1]
train_df.cache()
test_df.cache()
print(train_df.count())
print(test_df.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">93304
# 23454
# </div>

# %% [markdown]
# #### Convert categorical columns to indexes

# %%
# Convert categorical columns to indexes
categorical_cols = ["year", "genre"]
train_df_numeric, test_df_numeric = indexStringColumns(train_df, test_df, categorical_cols)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train_df_numeric.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>duration</th><th>key</th><th>loudness</th><th>mode</th><th>start_of_fade_out</th><th>tempo</th><th>time_signature</th><th>lyrics_embedding</th><th>year</th><th>genre</th></tr></thead><tbody><tr><td>277.15873</td><td>1</td><td>-16.184</td><td>1</td><td>273.908</td><td>107.924</td><td>4</td><td>List(-0.031483667242415074, -0.10618563572670653, 0.5031864509825975, -1.5874433166089472, 0.7748701095651014)</td><td>9.0</td><td>12.0</td></tr><tr><td>183.35302</td><td>9</td><td>-15.101</td><td>1</td><td>173.935</td><td>97.915</td><td>4</td><td>List(-0.11660222896747291, 0.03755403051525354, 0.21827486750483513, -1.950095944352448, 0.7970992401689291)</td><td>7.0</td><td>12.0</td></tr><tr><td>183.48363</td><td>8</td><td>-15.415</td><td>1</td><td>175.177</td><td>84.918</td><td>4</td><td>List(-0.5511955075175026, -0.026105823945634217, 0.15994950634788493, -2.8463053813831385, 0.7133604537657633)</td><td>7.0</td><td>12.0</td></tr><tr><td>184.73751</td><td>10</td><td>-14.749</td><td>0</td><td>179.241</td><td>99.602</td><td>4</td><td>List(-0.9219694815482944, -0.13360975734516978, 0.09295503515005112, -1.179882988223806, 0.6906660223901272)</td><td>7.0</td><td>11.0</td></tr><tr><td>196.44036</td><td>7</td><td>-15.593</td><td>1</td><td>189.608</td><td>153.755</td><td>3</td><td>List(-0.6670095400995243, 0.11506408996538701, 0.5347637996172249, -2.3407715423431217, 0.8673367663365552)</td><td>7.0</td><td>3.0</td></tr><tr><td>210.75546</td><td>8</td><td>-15.274</td><td>1</td><td>205.694</td><td>94.662</td><td>5</td><td>List(-0.819624266526194, 0.13409620176138576, -0.5517601467929292, -2.367925111946597, 1.1398944478511492)</td><td>7.0</td><td>8.0</td></tr><tr><td>245.44608</td><td>9</td><td>-21.15</td><td>0</td><td>239.543</td><td>93.092</td><td>4</td><td>List(-0.4799413123495273, 0.644405758270138, -0.3276586180603182, -2.585679351573659, 0.919800955620972)</td><td>7.0</td><td>12.0</td></tr><tr><td>250.3571</td><td>10</td><td>-12.886</td><td>1</td><td>243.688</td><td>70.407</td><td>5</td><td>List(0.41723413544814814, 0.5724066215122274, 0.8571092899283165, -2.908158897130929, 1.1910362219061759)</td><td>7.0</td><td>8.0</td></tr><tr><td>314.43546</td><td>10</td><td>-23.093</td><td>0</td><td>291.172</td><td>75.182</td><td>1</td><td>List(-0.9050677694751234, 0.8024701687647424, -0.17525894834139083, -2.67306925962537, 0.8380430637527321)</td><td>7.0</td><td>12.0</td></tr><tr><td>118.30812</td><td>2</td><td>-18.034</td><td>1</td><td>113.093</td><td>79.765</td><td>1</td><td>List(-0.10264137551098704, 0.8392042293920216, 0.06756274577185332, -3.720788072570261, 1.6302583571299014)</td><td>8.0</td><td>8.0</td></tr><tr><td>137.22077</td><td>7</td><td>-17.25</td><td>1</td><td>131.64</td><td>95.44</td><td>4</td><td>List(-0.7809846368720031, -0.3385588822985809, -0.3851563292148622, -0.5149584544994371, 0.2598618139983019)</td><td>8.0</td><td>3.0</td></tr><tr><td>148.27057</td><td>6</td><td>-11.475</td><td>1</td><td>144.254</td><td>130.271</td><td>4</td><td>List(-0.6108525629278343, 0.1657450141139188, -0.02923585850534574, -2.5371054881164485, 0.8073758407724353)</td><td>8.0</td><td>0.0</td></tr><tr><td>159.00689</td><td>11</td><td>-22.701</td><td>1</td><td>154.715</td><td>114.646</td><td>3</td><td>List(-0.05790212935906776, 0.31943832334289524, 0.3349981823183121, -2.1266708414050495, 0.7356791796598663)</td><td>8.0</td><td>12.0</td></tr><tr><td>175.0722</td><td>6</td><td>-12.393</td><td>1</td><td>170.272</td><td>78.137</td><td>1</td><td>List(0.1894802089055739, 0.3935152560185928, 0.8052444956286461, -2.357005174969201, 0.3887414386352668)</td><td>8.0</td><td>12.0</td></tr><tr><td>177.03138</td><td>0</td><td>-18.709</td><td>0</td><td>170.632</td><td>79.584</td><td>4</td><td>List(-0.9659530375510046, 0.00888102586683073, -0.6392909561594327, -0.6807438960196833, 0.6248903645831904)</td><td>8.0</td><td>8.0</td></tr><tr><td>191.242</td ...

# %% [markdown]
# #### One Hot Encoding of categorical columns

# %%
# Get one-hot encoding of the categorical columns - except genre, which is the dependent variable
categorical_cols.remove('genre')
train_df_ohe, test_df_ohe = oneHotEncodeColumns(train_df_numeric, test_df_numeric, categorical_cols)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
test_df_ohe.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>duration</th><th>key</th><th>loudness</th><th>mode</th><th>start_of_fade_out</th><th>tempo</th><th>time_signature</th><th>lyrics_embedding</th><th>genre</th><th>year</th></tr></thead><tbody><tr><td>194.11546</td><td>0</td><td>-12.99</td><td>1</td><td>188.801</td><td>160.108</td><td>1</td><td>List(0.06951100105858024, 0.918235227561501, 0.3457141685354359, -2.4571679100048427, 0.32572315203792906)</td><td>12.0</td><td>Map(vectorType -> sparse, length -> 10, indices -> List(7), values -> List(1.0))</td></tr><tr><td>148.34893</td><td>7</td><td>-15.937</td><td>1</td><td>143.343</td><td>86.701</td><td>4</td><td>List(-0.10093192497098988, 0.5270097218792547, -0.20730323425748132, -2.6212513351474294, 0.8508528613908724)</td><td>3.0</td><td>Map(vectorType -> sparse, length -> 10, indices -> List(8), values -> List(1.0))</td></tr><tr><td>153.28608</td><td>9</td><td>-19.7</td><td>1</td><td>149.722</td><td>103.632</td><td>1</td><td>List(-0.16473731404495617, 0.44556468488216133, 0.1399134922595251, -3.0198523972242595, 1.1343182717405613)</td><td>12.0</td><td>Map(vectorType -> sparse, length -> 10, indices -> List(8), values -> List(1.0))</td></tr><tr><td>158.64118</td><td>10</td><td>-20.742</td><td>1</td><td>148.706</td><td>166.442</td><td>4</td><td>List(-1.095739191377544, -0.33569403283332505, 0.5700708655295549, -1.514370242771865, 0.18855515158631733)</td><td>8.0</td><td>Map(vectorType -> sparse, length -> 10, indices -> List(8), values -> List(1.0))</td></tr><tr><td>162.58567</td><td>6</td><td>-14.574</td><td>1</td><td>155.91</td><td>115.29</td><td>4</td><td>List(-0.07279156959490983, 0.6489708108724807, -1.155317559720963, -2.6320624480323724, 0.8732775573116383)</td><td>12.0</td><td>Map(vectorType -> sparse, length -> 10, indices -> List(8), values -> List(1.0))</td></tr><tr><td>110.86322</td><td>10</td><td>-8.991</td><td>1</td><td>107.462</td><td>180.031</td><td>4</td><td>List(-0.14080675253971367, -0.058336252980587776, -0.33362146721205166, -2.1315276742349134, 0.7512298199429847)</td><td>3.0</td><td>Map(vectorType -> sparse, length -> 10, indices -> List(6), values -> List(1.0))</td></tr><tr><td>118.282</td><td>10</td><td>-11.087</td><td>0</td><td>111.868</td><td>101.252</td><td>4</td><td>List(-0.15470334921439408, -0.06986111088048833, -0.13852788872926342, -1.5099580670350612, 0.615566268291792)</td><td>3.0</td><td>Map(vectorType -> sparse, length -> 10, indices -> List(6), values -> List(1.0))</td></tr><tr><td>119.09179</td><td>8</td><td>-12.564</td><td>0</td><td>113.847</td><td>92.749</td><td>4</td><td>List(-0.04737658899378132, 0.5871402372245316, -0.3557645679191426, -2.3197033848437303, 1.3889184022271954)</td><td>8.0</td><td>Map(vectorType -> sparse, length -> 10, indices -> List(6), values -> List(1.0))</td></tr><tr><td>128.49587</td><td>7</td><td>-11.757</td><td>1</td><td>123.855</td><td>87.996</td><td>4</td><td>List(0.13386038961862004, 0.63374834393026, 0.12477801731829323, -2.7262932199067365, 0.834827324903723)</td><td>3.0</td><td>Map(vectorType -> sparse, length -> 10, indices -> List(6), values -> List(1.0))</td></tr><tr><td>130.95138</td><td>6</td><td>-8.865</td><td>0</td><td>126.973</td><td>85.738</td><td>4</td><td>List(-0.25718177392220887, 0.3255126940939814, -0.3637891166701252, -2.8861798196962205, 0.8777768702826605)</td><td>4.0</td><td>Map(vectorType -> sparse, length -> 10, indices -> List(6), values -> List(1.0))</td></tr><tr><td>135.99302</td><td>5</td><td>-17.294</td><td>1</td><td>135.993</td><td>192.044</td><td>4</td><td>List(-0.3355870588754232, 0.31418291208549187, -0.6159561582912619, -2.6743898369945014, 1.3068733123059457)</td><td>0.0</td><td>Map(vectorType -> sparse, length -> 10, indices -> List(6), values -> List(1.0))</td></tr><tr><td>137.69098</td><td>4</td><td>-12.314</td><td>1</td><td>132.807</td><td>113.342</td><td>1</td><td>List(0.06360285723389222, 0.83517859692460 ...

# %% [markdown]
# #### VectorAssembler

# %%
# Convert lyrics embedding array to dense vector
list_to_vector_udf = udf(lambda l: Vectors.dense(l), VectorUDT())
train_df_ohe = train_df_ohe.withColumn("lyrics_vector", list_to_vector_udf("lyrics_embedding")).drop('lyrics_embedding')
test_df_ohe = test_df_ohe.withColumn("lyrics_vector", list_to_vector_udf("lyrics_embedding")).drop('lyrics_embedding')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Use VectorAssembler to prepare data for the model
input_cols = train_df_ohe.columns[:]
input_cols.remove('genre')
va = VectorAssembler(outputCol="features", inputCols=input_cols) #except the last col.

train = va.transform(train_df_ohe).select("features", "genre").withColumnRenamed("genre", "label")
train = train.select("features", "label")

test = va.transform(test_df_ohe).select("features", "genre").withColumnRenamed("genre", "label")
test = test.select("features", "label")

# Cache the train and test data
train.cache()
test.cache()
print(train.count())
print(test.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">93304
# 23454
# </div>

# %% [markdown]
# #### Fit Random Forest Model

# %% [markdown]
# Cross validation running time is around 2 minutes. Following 2 code blocks can be commented out.

# %%
#Do cross validation to find the best hyperparameters
rf = RandomForestClassifier()
mce = MulticlassClassificationEvaluator()
paramGrid = ParamGridBuilder().addGrid(rf.maxDepth, [3, 5, 7]).addGrid(rf.minInstancesPerNode, [1, 3, 5]).build()
cv = CrossValidator(estimator=rf, 
                    evaluator=mce, 
                    numFolds=3, 
                    estimatorParamMaps=paramGrid)
cvmodel = cv.fit(train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Check hyperparameter results
params = [{p.name: v for p, v in m.items()} for m in cvmodel.getEstimatorParamMaps()]
import pandas as pd
pd.DataFrame.from_dict([
    {cvmodel.getEvaluator().getMetricName(): metric, **ps} 
    for ps, metric in zip(params, cvmodel.avgMetrics)
])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>f1</th>
#       <th>maxDepth</th>
#       <th>minInstancesPerNode</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.645683</td>
#       <td>3</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.645683</td>
#       <td>3</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.645683</td>
#       <td>3</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.649640</td>
#       <td>5</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.649566</td>
#       <td>5</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.649764</td>
#       <td>5</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.650723</td>
#       <td>7</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0.651053</td>
#       <td>7</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>0.650976</td>
#       <td>7</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# We can maxDepth=7 and minInstancesPerNode=3 as the parameters for the Random Forest model based on the cross validation scores

# %%
# Build a Random Forest Classifier to predict the probability of a song belonging to a certain genre
rf = RandomForestClassifier(maxDepth=7, minInstancesPerNode=3)
rfmodel = rf.fit(train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Test Set Evaluation

# %%
# Get predictions on the test set
rfpredicts = rfmodel.transform(test)

# Calculate F1 Score
metrics = MulticlassClassificationEvaluator()
print(f"F1: {metrics.evaluate(rfpredicts):.4f}")

# Calculate Accuracy
metrics.setMetricName("accuracy") 
print(f"Accuracy: {metrics.evaluate(rfpredicts):.4f}")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">F1: 0.6492
# Accuracy: 0.7463
# </div>

# %% [markdown]
# #### Logistic Regression Model

# %%
lr = LogisticRegression(regParam=0.01, maxIter=1000, fitIntercept=True)
lrmodel = lr.fit(train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Get predictions on the test set
lrpredicts = lrmodel.transform(test)

# Calculate F1 Score
metrics.setMetricName("f1") 
print(f"F1: {metrics.evaluate(lrpredicts):.4f}")

# Calculate Accuracy
metrics.setMetricName("accuracy") 
print(f"Accuracy: {metrics.evaluate(lrpredicts):.4f}")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">F1: 0.6482
# Accuracy: 0.7445
# </div>

# %% [markdown]
# Logistic Regression did equally good as the Random Forest model. We could choose either model.

# %% [markdown]
# #### Try class weights for Random Forest model

# %%
# Try classes weights
weight_df = train.groupby('label').count()
weight_df.cache()
train_len = train.count()
n_classes = weight_df.count()
weight_df = weight_df.withColumn('weights', log(train_len / (weight_df['count'])))

# Merge weights with original df
weight_df = weight_df.drop('count')
train_w = train.join(weight_df, 'label')
test_w = test.join(weight_df, 'label')

# Cache train and test 
train_w.cache()
test_w.cache()
print(train_w.count())
print(test_w.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">93304
# 23454
# </div>

# %%
# Train weighted RF model
rf = RandomForestClassifier(maxDepth=7, minInstancesPerNode=3, 
                              featuresCol='features', labelCol='label', weightCol='weights', seed=0)
rfmodel = rf.fit(train_w)

# Get predictions on the test set
rfpredicts = rfmodel.transform(test_w)
# Calculate F1 Score
metrics = MulticlassClassificationEvaluator()
print(f"F1: {metrics.evaluate(rfpredicts):.4f}")
# Calculate Accuracy
metrics.setMetricName("accuracy") 
print(f"Accuracy: {metrics.evaluate(rfpredicts):.4f}")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">F1: 0.6336
# Accuracy: 0.6486
# </div>

# %% [markdown]
# Unfortunately, the weighted RF model did not improve the previous model. Hence, we can choose the original unweighted RF model as the final model.

# %%
print(f'Time taken to run: {time() - start:.2f} seconds')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Time taken to run: 308.19 seconds
# </div>

# %%
spark.stop()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
